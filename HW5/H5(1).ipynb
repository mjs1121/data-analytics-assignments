# %%
# Question 1 - Import data
import pandas as pd
import numpy as np
import os

path = "D:\\Documents\\DAAN862\\"
os.chdir(path)
file_reg = "Registration.csv"
file_course = "Course_info.xlsx"

reg_pd = pd.read_csv(file_reg)
course_pd = pd.read_excel(file_course)

# Question 2 - Explore and Clean Registration
# We will create a new data frame containing any rows
# with identified nulls to see how/what needs handled
reg_pd
# As shown, the registration file contains 4900 rows
# of various named students with each row corresponding
# to a semester date and coursename
# Out:
#      Student name semester new
# 0       Bill Mumy    Fall 2004  \
# 1       Bill Mumy    Fall 2000
# 2       Bill Mumy    Fall 2003
# 3       Bill Mumy    Fall 2005
# 4       Bill Mumy    Fall 2000
# ...           ...          ...
# 4895  Stacy Keach  Summer 2001
# 4896  Ann Landers  Summer 2004
# 4897  Ann Landers  Summer 2004
# 4898    Tyne Daly  Summer 2004
# 4899    Tyne Daly  Summer 2004
#
#                                            coursename
# 0                             BEHAVIORAL PHARMACOLOGY
# 1                             AMERICAN FOREIGN POLICY
# 2                               DRUGS, BRAIN AND MIND
# 3                          Environmental Case Studies
# 4                             COMPUTER LINEAR ALGEBRA
# ...                                               ...
# 4895                         CELL. BIOL. And BIOCHEM.
# 4896                            AMERICAN HEALT POLICY
# 4897                             ANALYTICAL MECHANICS
# 4898                            COMPUT LINEAR ALGEBRA
# 4899  EXPERIMENTAL WRITING SEM: The Ecology of Poetry
#
# [4900 rows x 3 columns]

# %%
# Some potentially useful information as well:
# Number of unique students and classes registered
unique_students = reg_pd['Student name'].unique()
unique_courses = reg_pd['coursename'].unique()

print("Unique Number of Students: " + str(len(unique_students)))
print("Unique Number of Course: " + str(len(unique_courses)))
# Out:
# Unique Number of Students: 448
# Unique Number of Course: 169

# %%
# We should also look for duplicates within registration,
# so we will pull from a few names to see if we can find any
display(reg_pd[reg_pd['Student name'].str.contains('Bill Mumy')])
# Out:
#    Student name semester new
# 0     Bill Mumy    Fall 2004  \
# 1     Bill Mumy    Fall 2000
# 2     Bill Mumy    Fall 2003
# 3     Bill Mumy    Fall 2005
# 4     Bill Mumy    Fall 2000
# 5     Bill Mumy  Spring 2002
# 6     Bill Mumy  Spring 2003
# 7     Bill Mumy  Spring 2003
# 8     Bill Mumy  Spring 2003
# 9     Bill Mumy    Fall 2002
# 10    Bill Mumy    Fall 2002
# 11    Bill Mumy    Fall 2002
# 12    Bill Mumy  Spring 2005
# 13    Bill Mumy  Spring 2005
# 14    Bill Mumy  Spring 2005
# 15    Bill Mumy    Fall 2004
# 16    Bill Mumy    Fall 2004
# 17    Bill Mumy    Fall 2004
# 18    Bill Mumy  Spring 2003
# 19    Bill Mumy  Spring 2003
# 20    Bill Mumy  Spring 2003
# 21    Bill Mumy  Spring 2002
# 22    Bill Mumy  Spring 2002
# 23    Bill Mumy  Spring 2002
#
#                                            coursename
# 0                             BEHAVIORAL PHARMACOLOGY
# 1                             AMERICAN FOREIGN POLICY
# 2                               DRUGS, BRAIN AND MIND
# 3                          Environmental Case Studies
# 4                             COMPUTER LINEAR ALGEBRA
# 5                           ART, from ancient to 1945
# 6                            CONTEMP ART - since 1945
# 7                            CONTEMP ART - since 1945
# 8                            CONTEMP ART - since 1945
# 9                                ANALYTICAL MECHANICS
# 10                               ANALYTICAL MECHANICS
# 11                               ANALYTICAL MECHANICS
# 12                           CONTEMPORARY AFRICAN ART
# 13                           CONTEMPORARY AFRICAN ART
# 14                           CONTEMPORARY AFRICAN ART
# 15                               CEL BIO BIOCHEMISTRY
# 16                               CEL BIO BIOCHEMISTRY
# 17                               CEL BIO BIOCHEMISTRY
# 18                      CELL BIOLOGY and BIOCHEMISTRY
# 19                      CELL BIOLOGY and BIOCHEMISTRY
# 20                      CELL BIOLOGY and BIOCHEMISTRY
# 21  BIBLE IN TRANSLATION: Proverbs, Ecclesiastes, ...
# 22  BIBLE IN TRANSLATION: Proverbs, Ecclesiastes, ...
# 23  BIBLE IN TRANSLATION: Proverbs, Ecclesiastes, ...

# %%
# We can see that there are in fact duplicates in the entries
# Create a new table with duplicates removes
reg_pd_dups = reg_pd.drop_duplicates()
display(reg_pd_dups[reg_pd_dups['Student name'].str.contains('Bill Mumy')])
# Out:
#    Student name semester new
# 0     Bill Mumy    Fall 2004  \
# 1     Bill Mumy    Fall 2000
# 2     Bill Mumy    Fall 2003
# 3     Bill Mumy    Fall 2005
# 4     Bill Mumy    Fall 2000
# 5     Bill Mumy  Spring 2002
# 6     Bill Mumy  Spring 2003
# 9     Bill Mumy    Fall 2002
# 12    Bill Mumy  Spring 2005
# 15    Bill Mumy    Fall 2004
# 18    Bill Mumy  Spring 2003
# 21    Bill Mumy  Spring 2002
#
#                                            coursename
# 0                             BEHAVIORAL PHARMACOLOGY
# 1                             AMERICAN FOREIGN POLICY
# 2                               DRUGS, BRAIN AND MIND
# 3                          Environmental Case Studies
# 4                             COMPUTER LINEAR ALGEBRA
# 5                           ART, from ancient to 1945
# 6                            CONTEMP ART - since 1945
# 9                                ANALYTICAL MECHANICS
# 12                           CONTEMPORARY AFRICAN ART
# 15                               CEL BIO BIOCHEMISTRY
# 18                      CELL BIOLOGY and BIOCHEMISTRY
# 21  BIBLE IN TRANSLATION: Proverbs, Ecclesiastes, ...

# %%
# Obtain a list of nulls found in the data set
reg_nulls = reg_pd_dups[reg_pd_dups.isnull().any(axis = 1)]
display(reg_nulls)
# Out:
#      Student name semester new coursename
# 1650   John Jakes  Summer 2003        NaN

# %%
# As identified, only one row has a missing
# value, which is row 1650 with a missing 
# coursename. In this case, we should just 
# drop this row in the original data frame
reg_pd_clean = reg_pd_dups.dropna(how = 'any')
display(reg_pd_clean.iloc[1648:1652])

# Before going further, we should also take a
# look at some unique values to see if any
# accidental duplicates exist especially in
# regards to the coursenames
unique_courses = reg_pd_clean['coursename'].unique()
display(sorted(unique_courses))

# With some skimming, its apparent that a lot
# of classes have similar names
# and we may want to rename them to a common name
# Before doing so, we should analyze the courses
# listed in the excel sheet to determine what that 
# common name should be
# Out:
#           Student name semester new
# 2198  Barbara Delinsky  Spring 2001  \
# 2199        Bob Barker    Fall 2000
# 2200    Lawrence Block  Summer 2004
# 2201    Lawrence Block  Summer 2002
#
#                                            coursename
# 2198                    EARLY MESOPOTAMIAN HIST - SOC
# 2199  EXPERIMENTAL WRITING SEM: The Ecology of Poetry
# 2200                          AMERICAN FOREIGN POLICY
# 2201                            COMPUT LINEAR ALGEBRA
# ['1000 YRS MUSICAL LISTENG: 1000 YRS MUSICAL LISTENG',
#  '19TH-CENT BRITISH LIT',
#  '19TH-CENT NOVEL',
#  '1ST YR CLASSICAL CHIN II',
#  '20TH-CENT POETRY',
#  '20th Century Russian Literature: Fiction and Reality',
#  'A WORLD AT WAR',
#  'ABNORMAL PSYCHOLOGY',
#  'ACCEL INTERMD PORTUGUESE',
#  'ACCEL INTERMEDIATE SPAN',
#  'ACCELERATED HINDI',
#  'ACCELERATED INTERMD GRMN',
#  'AESTHETICS',
#  'AFGHANISTAN & ISLAMISM: AFGHANISTAN & ISLAMISM',
#  'AFRICAN LANG. & CULTURE',
#  'AFRICAN-AMERICAN LIT',
#  'AFRICAN-AMERICAN LIT: AFRICAN-AMER LIT:CHANGE',
#  'AFRO AMER HIST 1876-PRES',
#  'AMER POST-1800: BF SEM: MODERN AMERICAN CITIES',
#  'AMER REVOLUTION',
#  'AMERICA IN THE 1960S',
#  'AMERICAN FOREIGN POLICY',
#  'AMERICAN HEALT POLICY',
#  'AMERICAN HEALTH POLICY',
#  'AMERICAN MUSICAL THEATRE',
#  'AMERICAN POETRY',
#  'AMERICAN SOCIETY',
#  'AMERICAN SOUTH 1861-PRES',
#  'ANAL METH ECON, LAW MED',
#  'ANALYTICAL MECHANICS',
#  'ANALYZING THE POL WORLD',
#  'ANCIENT ROME',
#  'ANIMAL BEHAVIOR',
#  'ANIMAL COGNITION',
#  'ANTH & THE MODERN WORLD: Afghanistan, Iran, Pakistan',
#  'ANTH OF GLOBAL LABOR: Anthropology of Global Labor',
#  'ANTHROPOLOGY & CINEMA',
#  'ANTHROPOLOGY AND CINEMA',
#  'APPLIED MUSIC',
#  'ARCHAEOL GREC-ROM RELIG',
#  'ARCHAEOL OF PRIVATE LIFE',
#  'ARCHAEOLOGY OF THE INCA',
#  'ART & RELIGION',
#  'ART - ancient to 1945',
#  'ART - from ancient to 1945',
#  'ART AND BUSINESS OF FILM',
#  'ART AND RELIGION',
#  'ART ancient to 1945',
#  'ART, from ancient to 1945',
#  'ART: ancient to 1945',
#  'ASIAN AMER COMM FLD WRK',
#  'AUGUSTAN CULTRL REVOL',
#  'BECOMING HUMAN',
#  'BEG RDG/WRTG CHINESE II',
#  'BEHAVIORAL ECON & PSYCH',
#  'BEHAVIORAL PHARMACOLOGY',
#  'BEING HUMAN: Being Human: Biology, Culture & Human Diversity',
#  'BIBLE IN TRANSLATION: Proverbs, Ecclesiastes, and Job',
#  'BIOCHEMISTRY RESEARCH',
#  'BIOLOGICAL CHEMISTRY II',
#  'BRITAIN SINCE 1945',
#  'BRITISH POETRY 1660-1914',
#  'Business German - Micro Perspective',
#  'Business German A Micro Perspective',
#  'Business German, A Micro Perspective',
#  'Business German: A Micro Perspective',
#  'CEL BIO BIOCHEMISTRY',
#  'CEL and BIO and BIOCHEMISTRY',
#  'CELL BIOL & BIOCHEM',
#  'CELL BIOLOGY & BIOCHEM',
#  'CELL BIOLOGY and BIOCHEM',
#  'CELL BIOLOGY and BIOCHEMISTRY',
#  'CELL and BIO and BIOCHEMISTRY',
#  'CELL. BIOL. & BIOCHEM.',
#  'CELL. BIOL. And BIOCHEM.',
#  'COGNITIVE PSYCHOLOGY',
#  'COMM & THE PRESIDENCY',
#  'COMM and  THE PRESIDENCY',
#  'COMM, CHILDHOOD, & PLAY',
#  'COMMUNICATION BEHAVIOR',
#  'COMMUNICATIONS INTERNSHP',
#  'COMMUNICATIONS INTERNSHiP',
#  'COMMUNITY MATH TEACH PRO',
#  'COMP POL. WELFARE STATE',
#  'COMPARATIVE POLITICS',
#  'COMPUT LINEAR ALGEBRA',
#  'COMPUTER LINEAR ALGEBRA',
#  'CONTEMP ART - 1945 to PRESENT',
#  'CONTEMP ART - 1945 to today',
#  'CONTEMP ART - since 1945',
#  'CONTEMP ART:1945 to PRESENT',
#  'CONTEMPORARY AFRICAN ART',
#  'CONTEMPORARY AFRICAN-ART',
#  'CONTEMPORARY POL.THOUGHT',
#  'CONTEMPORARY SOCIO THEOR',
#  'CONTMP POL,POLICY,JOURN',
#  'CONVERSATION & WRITING',
#  'CONVERSATION AND COMPOSI',
#  'CREAT.NON-FICTION WRIT',
#  'CREAT.NON-FICTION WRIT: PEER TUTORING',
#  'CREATIVE WRITING: CREAT. WRITE: FICT/POET',
#  'CREATIVE WRITING: CREAT./POETRY & NON-FICT',
#  'CREATIVE WRITING: WRITING PERSONAL ESSAY',
#  'CRIME AND DETECTION: Dark Deeds',
#  'CURR ISSUES GLOBAL HEALT',
#  'Community Based Research on Health Disparities',
#  "DANTE'S DIVINE COMEDY",
#  "DEVIL'S PACT LIT/FILM",
#  'DIGITAL MEDIA & THE CITY',
#  'DIGITAL PHOTOGRAPHY',
#  'DNA, DIET, AND DISEASE: The Biology of Food',
#  'DOCUMENTARY WRITING',
#  'DRAMATURGY',
#  'DRUGS, BRAIN AND MIND',
#  'DRUGS, BRAIN, AND MIND',
#  'EARLY CINEMA',
#  'EARLY MESOPOTAM HIST - SOC',
#  'EARLY MESOPOTAM HIST/SOC',
#  'EARLY MESOPOTAMIAN HIST - SOC',
#  'ECONOMETRIC FORECASTING',
#  'ECONOMETRICS',
#  "EDGAR ALLAM POE'S SCIEN",
#  'ELECTROMAG II',
#  'ELEM BIBLICAL HEBREW II',
#  'ELEM CLASSICAL GREEK II',
#  'ELEM MODERN HEBREW I',
#  'ELEM MODERN HEBREW II',
#  'ELEM PERSIAN II',
#  'ELEMENTARY ARABIC II',
#  'ELEMENTARY FRENCH I',
#  'ELEMENTARY FRENCH II',
#  'ELEMENTARY GERMAN 1',
#  'ELEMENTARY GERMAN I',
#  'ENERGY,OIL&GLOBAL WARMIN',
#  'ENVIRONMENTAL GEOLOGY',
#  'ENVIRONMENTAL SYSTEMS II',
#  'EPIC TRADITIONS OF INDIA',
#  'EUR PRE-1800, BF SEM, UTOPIA',
#  'EUR PRE-1800: BF SEM: UTOPIA',
#  'EURO ART & CIV > 1400: RENAISSANCE TO CONTEMP',
#  "EURO INT'L REL SINCE WW One",
#  "EURO INT'L REL SINCE WW1",
#  "EURO INT'L REL SINCE WWI",
#  'EURO INTELL HIST 18 C.',
#  'EUROPE IN A WIDER WORLD',
#  'EVIDENCED BASED CRIME & JUSTICE POLICY',
#  'EVIDENCED BASED CRIME AND JUSTICE POLICY',
#  'EXPERIMENTAL WRITING SEM',
#  'EXPERIMENTAL WRITING SEM: The Ecology of Poetry',
#  'EYE, MIND AND IMAGE',
#  'Environmental Case Studies',
#  'Environmental Studies Research Seminar Junior Level',
#  'Environmental Studies Research Seminar for Juniors',
#  'FICTION WRITING WORKSHOP',
#  'FOOD/FEAST ARCH OF TABLE',
#  'FORENSIC ANTHROPOLOGY',
#  'FORMAL LOGIC I',
#  'FORMAL SEM AND COG SCI',
#  'FR FOR PROFESSIONS I',
#  'FR FOR PROFESSIONS II',
#  'FR LIT OF THE 19TH C: STUDIES IN THE 19TH C.',
#  'FRANCE & THE EUROP.UNION',
#  'FRANCE AND ITS OTHERS: Anthropology and French Modernism',
#  'FREEDOM OF EXPRESSION',
#  'FRENCH PHONETICS',
#  'FRESHWATER ECOLOGY',
#  'Feminist Theory: Feminism, Activism, and the Body',
#  'French Thought Since 1945']

# %%
# Question 3 - Explore and Clean Courses
# We will use the same tactic form Question 2
display(course_pd)

# Obtain any nulls
course_nulls = course_pd[course_pd.isnull().any(axis = 1)]
display(course_nulls)
# Since we have identified that a course exists
# without a name, this may be the missing coursename
# from the registration file. At this point, since 
# it is unclear if that is the actual course or just
# another clarical error, I will drop this course
# too. Given that all we know is that one student
# out of
# Out:
#    Course number                                       Course Name
# 0        ARTS400    EXPERIMENTAL WRITING SEM: The Ecology of Poetry  \
# 1        ARTS401                               ART: ancient to 1945
# 2        ARTS465                           ENVIRONMENTAL SYSTEMS II
# 3        ARTS486                            COMPUTER LINEAR ALGEBRA
# 4        ARTS512                               ANALYTICAL MECHANICS
# 5        ARTS514                                     A WORLD AT WAR
# 6        ARTS516                            BEHAVIORAL PHARMACOLOGY
# 7        ARTS518                           CONTEMPORARY AFRICAN ART
# 8        ARTS520                           FOOD/FEAST ARCH OF TABLE
# 9       ARTS488                               DEVIL'S PACT LIT/FILM
# 10       ARTS541                             AMERICAN SOCIAL POLICY
# 11      ARTS543                                    ART AND RELIGION
# 12       ARTS491                           CONTEMPORARY POL.THOUGHT
# 13      ARTS492       AFRICAN-AMERICAN LIT: AFRICAN-AMER LIT:CHANGE
# 14       ARTS493                             AMERICAN HEALTH POLICY
# 15       ARTS494               Business German: A Micro Perspective
# 16      ARTS495                            COMM and  THE PRESIDENCY
# 17       ARTS496                           French Thought Till 1945
# 18       ARTS497                      CONTEMP ART - 1945 to PRESENT
# 19      ARTS545   20th Century Russian Literature: Fiction and R...
# 20       ARTS547                           COMMUNICATIONS INTERNSHP
# 21       ARTS549                                 FRESHWATER ECOLOGY
# 22       ARTS551                                         AESTHETICS
# 23      ARTS553                           French Thought Since 1945
# 24       ARTS555                                     BECOMING HUMAN
# 25       ARTS485           EVIDENCED BASED CRIME AND JUSTICE POLICY
# 26       ARTS484                            EUROPE IN A WIDER WORLD
# 27      ARTS557                     19TH-CENTURY BRITISH LITERATURE
# 28      ARTS559                            AMERICAN SOUTH 1861-PRES
# 29       ARTS561                        AUGUSTAN CULTRAL REVOLUTION
# 30       ARTS565  Environmental Studies Research Seminar Junior ...
# 31      ARTS567                                                 NaN
# 32      ARTS569                              CELL. BIOL. & BIOCHEM.
# 33      ARTS571                            FRANCE & THE EUROP.UNION
# 34       ARTS573                            ANALYZING THE POL WORLD
# 35       ARTS575                    EARLY MESOPOTAM HISTORY/SOCIETY
# 36       ARTS577                           FRANCE & THE EUROP.UNION
# 37       ARTS579                              EARLY BALCAN HIST/SOC
# 38      ARTS581                                COMPARATIVE POLITICS
# 39      ARTS583                            BRITISH POETRY 1660-1914
# 40      ARTS585                           CONTEMPORARY SOCIO THEORY
# 41       ARTS587                               ELEMENTARY ARABIC II
#
#    Course Type
# 0            C
# 1            C
# 2            F
# 3            F
# 4            F
# 5            F
# 6            F
# 7            F
# 8            F
# 9            E
# 10           E
# 11           E
# 12           E
# 13           E
# 14           E
# 15           E
# 16           E
# 17           E
# 18           E
# 19           E
# 20           E
# 21           E
# 22           E
# 23           E
# 24           E
# 25           E
# 26           E
# 27           E
# 28           E
# 29           E
# 30           E
# 31           E
# 32           E
# 33           E
# 34           E
# 35           E
# 36           E
# 37           E
# 38           E
# 39           E
# 40           E
# 41           E
#    Course number Course Name  Course Type
# 31      ARTS567           NaN           E

# %%
# Remove the nulls since again, we are
# not sure what this class is supposed to be
course_pd_clean = course_pd.dropna(how = 'any')
display(course_pd_clean.iloc[29:33])
# Out:
#    Course number                                       Course Name
# 29       ARTS561                        AUGUSTAN CULTRAL REVOLUTION  \
# 30       ARTS565  Environmental Studies Research Seminar Junior ...
# 32      ARTS569                              CELL. BIOL. & BIOCHEM.
# 33      ARTS571                            FRANCE & THE EUROP.UNION
#
#    Course Type
# 29           E
# 30           E
# 32           E
# 33           E

# %%
# Let us take a look at how to solve
# the duplicating/repeating class names again
# we can display our unique matches via
# alpha-numerical sorting
sorted(unique_courses)
# Out:
# ['1000 YRS MUSICAL LISTENG: 1000 YRS MUSICAL LISTENG',
#  '19TH-CENT BRITISH LIT',
#  '19TH-CENT NOVEL',
#  '1ST YR CLASSICAL CHIN II',
#  '20TH-CENT POETRY',
#  '20th Century Russian Literature: Fiction and Reality',
#  'A WORLD AT WAR',
#  'ABNORMAL PSYCHOLOGY',
#  'ACCEL INTERMD PORTUGUESE',
#  'ACCEL INTERMEDIATE SPAN',
#  'ACCELERATED HINDI',
#  'ACCELERATED INTERMD GRMN',
#  'AESTHETICS',
#  'AFGHANISTAN & ISLAMISM: AFGHANISTAN & ISLAMISM',
#  'AFRICAN LANG. & CULTURE',
#  'AFRICAN-AMERICAN LIT',
#  'AFRICAN-AMERICAN LIT: AFRICAN-AMER LIT:CHANGE',
#  'AFRO AMER HIST 1876-PRES',
#  'AMER POST-1800: BF SEM: MODERN AMERICAN CITIES',
#  'AMER REVOLUTION',
#  'AMERICA IN THE 1960S',
#  'AMERICAN FOREIGN POLICY',
#  'AMERICAN HEALT POLICY',
#  'AMERICAN HEALTH POLICY',
#  'AMERICAN MUSICAL THEATRE',
#  'AMERICAN POETRY',
#  'AMERICAN SOCIETY',
#  'AMERICAN SOUTH 1861-PRES',
#  'ANAL METH ECON, LAW MED',
#  'ANALYTICAL MECHANICS',
#  'ANALYZING THE POL WORLD',
#  'ANCIENT ROME',
#  'ANIMAL BEHAVIOR',
#  'ANIMAL COGNITION',
#  'ANTH & THE MODERN WORLD: Afghanistan, Iran, Pakistan',
#  'ANTH OF GLOBAL LABOR: Anthropology of Global Labor',
#  'ANTHROPOLOGY & CINEMA',
#  'ANTHROPOLOGY AND CINEMA',
#  'APPLIED MUSIC',
#  'ARCHAEOL GREC-ROM RELIG',
#  'ARCHAEOL OF PRIVATE LIFE',
#  'ARCHAEOLOGY OF THE INCA',
#  'ART & RELIGION',
#  'ART - ancient to 1945',
#  'ART - from ancient to 1945',
#  'ART AND BUSINESS OF FILM',
#  'ART AND RELIGION',
#  'ART ancient to 1945',
#  'ART, from ancient to 1945',
#  'ART: ancient to 1945',
#  'ASIAN AMER COMM FLD WRK',
#  'AUGUSTAN CULTRL REVOL',
#  'BECOMING HUMAN',
#  'BEG RDG/WRTG CHINESE II',
#  'BEHAVIORAL ECON & PSYCH',
#  'BEHAVIORAL PHARMACOLOGY',
#  'BEING HUMAN: Being Human: Biology, Culture & Human Diversity',
#  'BIBLE IN TRANSLATION: Proverbs, Ecclesiastes, and Job',
#  'BIOCHEMISTRY RESEARCH',
#  'BIOLOGICAL CHEMISTRY II',
#  'BRITAIN SINCE 1945',
#  'BRITISH POETRY 1660-1914',
#  'Business German - Micro Perspective',
#  'Business German A Micro Perspective',
#  'Business German, A Micro Perspective',
#  'Business German: A Micro Perspective',
#  'CEL BIO BIOCHEMISTRY',
#  'CEL and BIO and BIOCHEMISTRY',
#  'CELL BIOL & BIOCHEM',
#  'CELL BIOLOGY & BIOCHEM',
#  'CELL BIOLOGY and BIOCHEM',
#  'CELL BIOLOGY and BIOCHEMISTRY',
#  'CELL and BIO and BIOCHEMISTRY',
#  'CELL. BIOL. & BIOCHEM.',
#  'CELL. BIOL. And BIOCHEM.',
#  'COGNITIVE PSYCHOLOGY',
#  'COMM & THE PRESIDENCY',
#  'COMM and  THE PRESIDENCY',
#  'COMM, CHILDHOOD, & PLAY',
#  'COMMUNICATION BEHAVIOR',
#  'COMMUNICATIONS INTERNSHP',
#  'COMMUNICATIONS INTERNSHiP',
#  'COMMUNITY MATH TEACH PRO',
#  'COMP POL. WELFARE STATE',
#  'COMPARATIVE POLITICS',
#  'COMPUT LINEAR ALGEBRA',
#  'COMPUTER LINEAR ALGEBRA',
#  'CONTEMP ART - 1945 to PRESENT',
#  'CONTEMP ART - 1945 to today',
#  'CONTEMP ART - since 1945',
#  'CONTEMP ART:1945 to PRESENT',
#  'CONTEMPORARY AFRICAN ART',
#  'CONTEMPORARY AFRICAN-ART',
#  'CONTEMPORARY POL.THOUGHT',
#  'CONTEMPORARY SOCIO THEOR',
#  'CONTMP POL,POLICY,JOURN',
#  'CONVERSATION & WRITING',
#  'CONVERSATION AND COMPOSI',
#  'CREAT.NON-FICTION WRIT',
#  'CREAT.NON-FICTION WRIT: PEER TUTORING',
#  'CREATIVE WRITING: CREAT. WRITE: FICT/POET',
#  'CREATIVE WRITING: CREAT./POETRY & NON-FICT',
#  'CREATIVE WRITING: WRITING PERSONAL ESSAY',
#  'CRIME AND DETECTION: Dark Deeds',
#  'CURR ISSUES GLOBAL HEALT',
#  'Community Based Research on Health Disparities',
#  "DANTE'S DIVINE COMEDY",
#  "DEVIL'S PACT LIT/FILM",
#  'DIGITAL MEDIA & THE CITY',
#  'DIGITAL PHOTOGRAPHY',
#  'DNA, DIET, AND DISEASE: The Biology of Food',
#  'DOCUMENTARY WRITING',
#  'DRAMATURGY',
#  'DRUGS, BRAIN AND MIND',
#  'DRUGS, BRAIN, AND MIND',
#  'EARLY CINEMA',
#  'EARLY MESOPOTAM HIST - SOC',
#  'EARLY MESOPOTAM HIST/SOC',
#  'EARLY MESOPOTAMIAN HIST - SOC',
#  'ECONOMETRIC FORECASTING',
#  'ECONOMETRICS',
#  "EDGAR ALLAM POE'S SCIEN",
#  'ELECTROMAG II',
#  'ELEM BIBLICAL HEBREW II',
#  'ELEM CLASSICAL GREEK II',
#  'ELEM MODERN HEBREW I',
#  'ELEM MODERN HEBREW II',
#  'ELEM PERSIAN II',
#  'ELEMENTARY ARABIC II',
#  'ELEMENTARY FRENCH I',
#  'ELEMENTARY FRENCH II',
#  'ELEMENTARY GERMAN 1',
#  'ELEMENTARY GERMAN I',
#  'ENERGY,OIL&GLOBAL WARMIN',
#  'ENVIRONMENTAL GEOLOGY',
#  'ENVIRONMENTAL SYSTEMS II',
#  'EPIC TRADITIONS OF INDIA',
#  'EUR PRE-1800, BF SEM, UTOPIA',
#  'EUR PRE-1800: BF SEM: UTOPIA',
#  'EURO ART & CIV > 1400: RENAISSANCE TO CONTEMP',
#  "EURO INT'L REL SINCE WW One",
#  "EURO INT'L REL SINCE WW1",
#  "EURO INT'L REL SINCE WWI",
#  'EURO INTELL HIST 18 C.',
#  'EUROPE IN A WIDER WORLD',
#  'EVIDENCED BASED CRIME & JUSTICE POLICY',
#  'EVIDENCED BASED CRIME AND JUSTICE POLICY',
#  'EXPERIMENTAL WRITING SEM',
#  'EXPERIMENTAL WRITING SEM: The Ecology of Poetry',
#  'EYE, MIND AND IMAGE',
#  'Environmental Case Studies',
#  'Environmental Studies Research Seminar Junior Level',
#  'Environmental Studies Research Seminar for Juniors',
#  'FICTION WRITING WORKSHOP',
#  'FOOD/FEAST ARCH OF TABLE',
#  'FORENSIC ANTHROPOLOGY',
#  'FORMAL LOGIC I',
#  'FORMAL SEM AND COG SCI',
#  'FR FOR PROFESSIONS I',
#  'FR FOR PROFESSIONS II',
#  'FR LIT OF THE 19TH C: STUDIES IN THE 19TH C.',
#  'FRANCE & THE EUROP.UNION',
#  'FRANCE AND ITS OTHERS: Anthropology and French Modernism',
#  'FREEDOM OF EXPRESSION',
#  'FRENCH PHONETICS',
#  'FRESHWATER ECOLOGY',
#  'Feminist Theory: Feminism, Activism, and the Body',
#  'French Thought Since 1945']

# %%
# One method to reduce duplicates - this
# is a better case scenario that but there are
# still going to be some missing matches.
# Reducing the threshold starts to cause
# some errorneous matches especially
# with "AMERICAN ..." and "ELEMENTARY ..."

import difflib
import re

for course in unique_courses:
    match = difflib.get_close_matches(course, course_pd_clean['Course Name '], n=1, cutoff=0.85)
    if match:
        print(course)
        print(match[0])
    
# Since these results look satisfactory
# we can apply the same loop to update
# the whole registration table now - 
# we will create a new dataframe with
# the updates to not overwrite the original
reg_courses_cleaned = reg_pd_clean.copy()

i = 0
for course in reg_courses_cleaned['coursename']:
    match = difflib.get_close_matches(course, course_pd_clean['Course Name '], n=1, cutoff=0.85)
    if match:
        reg_courses_cleaned['coursename'].iloc[i] = match[0]
    i += 1
# Out:
# BEHAVIORAL PHARMACOLOGY
# BEHAVIORAL PHARMACOLOGY
# COMPUTER LINEAR ALGEBRA
# COMPUTER LINEAR ALGEBRA
# ANALYTICAL MECHANICS
# ANALYTICAL MECHANICS
# CONTEMPORARY AFRICAN ART
# CONTEMPORARY AFRICAN ART
# COMPUT LINEAR ALGEBRA
# COMPUTER LINEAR ALGEBRA
# A WORLD AT WAR
# A WORLD AT WAR
# AMERICAN SOUTH 1861-PRES
# AMERICAN SOUTH 1861-PRES
# ELEMENTARY ARABIC II
# ELEMENTARY ARABIC II
# AMERICAN HEALTH POLICY
# AMERICAN HEALTH POLICY
# CONTEMPORARY POL.THOUGHT
# CONTEMPORARY POL.THOUGHT
# COMMUNICATIONS INTERNSHP
# COMMUNICATIONS INTERNSHP
# FOOD/FEAST ARCH OF TABLE
# FOOD/FEAST ARCH OF TABLE
# CELL. BIOL. & BIOCHEM.
# CELL. BIOL. & BIOCHEM.
# AMERICAN HEALT POLICY
# AMERICAN HEALTH POLICY
# EUROPE IN A WIDER WORLD
# EUROPE IN A WIDER WORLD
# FRANCE & THE EUROP.UNION
# FRANCE & THE EUROP.UNION
# 20th Century Russian Literature: Fiction and Reality
# 20th Century Russian Literature: Fiction and Reality
# FRESHWATER ECOLOGY
# FRESHWATER ECOLOGY
# EXPERIMENTAL WRITING SEM: The Ecology of Poetry
# EXPERIMENTAL WRITING SEM: The Ecology of Poetry
# AFRICAN-AMERICAN LIT: AFRICAN-AMER LIT:CHANGE
# AFRICAN-AMERICAN LIT: AFRICAN-AMER LIT:CHANGE
# ART - ancient to 1945
# ART: ancient to 1945
# Environmental Studies Research Seminar for Juniors
# Environmental Studies Research Seminar Junior Level
# ART ancient to 1945
# ART: ancient to 1945
# ART AND RELIGION
# ART AND RELIGION
# AESTHETICS
# AESTHETICS
# COMPARATIVE POLITICS
# COMPARATIVE POLITICS
# ANALYZING THE POL WORLD
# ANALYZING THE POL WORLD
# BECOMING HUMAN
# BECOMING HUMAN
# Business German: A Micro Perspective
# Business German: A Micro Perspective
# ENVIRONMENTAL SYSTEMS II
# ENVIRONMENTAL SYSTEMS II
# CELL BIOL & BIOCHEM
# CELL. BIOL. & BIOCHEM.
# French Thought Since 1945
# French Thought Since 1945
# DEVIL'S PACT LIT/FILM
# DEVIL'S PACT LIT/FILM
# EVIDENCED BASED CRIME & JUSTICE POLICY
# EVIDENCED BASED CRIME AND JUSTICE POLICY
# BRITISH POETRY 1660-1914
# BRITISH POETRY 1660-1914
# COMM and  THE PRESIDENCY
# COMM and  THE PRESIDENCY
# CELL. BIOL. And BIOCHEM.
# CELL. BIOL. & BIOCHEM.
# Environmental Studies Research Seminar Junior Level
# Environmental Studies Research Seminar Junior Level
# Business German, A Micro Perspective
# Business German: A Micro Perspective
# CONTEMPORARY SOCIO THEOR
# CONTEMPORARY SOCIO THEORY
# CELL BIOLOGY & BIOCHEM
# CELL. BIOL. & BIOCHEM.
# AUGUSTAN CULTRL REVOL
# AUGUSTAN CULTRAL REVOLUTION
# Business German A Micro Perspective
# Business German: A Micro Perspective
# CONTEMP ART - 1945 to PRESENT
# CONTEMP ART - 1945 to PRESENT
# ART & RELIGION
# ART AND RELIGION
# COMMUNICATIONS INTERNSHiP
# COMMUNICATIONS INTERNSHP
# COMM & THE PRESIDENCY
# COMM and  THE PRESIDENCY
# ART: ancient to 1945
# ART: ancient to 1945
# CONTEMPORARY AFRICAN-ART
# CONTEMPORARY AFRICAN ART
# Business German - Micro Perspective
# Business German: A Micro Perspective
# EVIDENCED BASED CRIME AND JUSTICE POLICY
# EVIDENCED BASED CRIME AND JUSTICE POLICY
# CONTEMP ART:1945 to PRESENT
# CONTEMP ART - 1945 to PRESENT
# EARLY MESOPOTAM HIST/SOC
# EARLY MESOPOTAM HISTORY/SOCIETY

# %%
# We can see how the update matched index
# 1766 to the coursename from Course_info.xlsx)
display(reg_pd_clean.iloc[1765:1767])
display(reg_courses_cleaned.iloc[1765:1767])

# We will leave the matching at that for now.
# Out:
#         Student name semester new                coursename
# 2351  Lorne Michaels    Fall 2001     COMPUT LINEAR ALGEBRA
# 2352  Lorne Michaels    Fall 2001  FOOD/FEAST ARCH OF TABLE
#         Student name semester new                coursename
# 2351  Lorne Michaels    Fall 2001   COMPUTER LINEAR ALGEBRA
# 2352  Lorne Michaels    Fall 2001  FOOD/FEAST ARCH OF TABLE

# %%
# Question 4 - Which course has the highest registration?
display(reg_courses_cleaned['coursename'].value_counts())

# Computer Linear Algebra appears to be the most common
# As a comparison from our non-matched dataframe
display(reg_pd_clean['coursename'].value_counts())
# Out:
# coursename
# COMPUTER LINEAR ALGEBRA                  325
# Environmental Case Studies               286
# A WORLD AT WAR                           269
# BEHAVIORAL PHARMACOLOGY                  260
# ANALYTICAL MECHANICS                     256
#                                         ...
# ASIAN AMER COMM FLD WRK                    1
# FR FOR PROFESSIONS II                      1
# ELEM CLASSICAL GREEK II                    1
# ANIMAL BEHAVIOR                            1
# CREAT.NON-FICTION WRIT: PEER TUTORING      1
# Name: count, Length: 151, dtype: int64
# coursename
# COMPUT LINEAR ALGEBRA                    303
# Environmental Case Studies               286
# A WORLD AT WAR                           269
# BEHAVIORAL PHARMACOLOGY                  260
# ANALYTICAL MECHANICS                     256
#                                         ...
# FR FOR PROFESSIONS II                      1
# ELEM CLASSICAL GREEK II                    1
# ANIMAL BEHAVIOR                            1
# DRUGS, BRAIN, AND MIND                     1
# CREAT.NON-FICTION WRIT: PEER TUTORING      1
# Name: count, Length: 168, dtype: int64

# %%
# Question 5 - Inner join the two datasets
reg_merged = pd.merge(reg_courses_cleaned, 
         course_pd_clean.rename(columns={'Course Name ': 'coursename'}), 
         on='coursename', how='inner')

# Using merge, we can now see the full frame
# of each student's registration containing 
# not only the course name but also number and
# type

display(reg_merged)
# Out:
#            Student name semester new                       coursename
# 0             Bill Mumy    Fall 2004          BEHAVIORAL PHARMACOLOGY  \
# 1     Geraldine Ferraro  Summer 2004          BEHAVIORAL PHARMACOLOGY
# 2         Laura Lippman    Fall 2004          BEHAVIORAL PHARMACOLOGY
# 3           Dom DeLuise    Fall 2000          BEHAVIORAL PHARMACOLOGY
# 4           Sally Field  Summer 2001          BEHAVIORAL PHARMACOLOGY
# ...                 ...          ...                              ...
# 2233       Pamela Jones    Fall 2001    CONTEMP ART - 1945 to PRESENT
# 2234        Rita Moreno    Fall 2001    CONTEMP ART - 1945 to PRESENT
# 2235         Tony Blair    Fall 2004    CONTEMP ART - 1945 to PRESENT
# 2236        Edward Koch    Fall 2004    CONTEMP ART - 1945 to PRESENT
# 2237       Betty Hutton    Fall 2000  EARLY MESOPOTAM HISTORY/SOCIETY
#
#      Course number Course Type
# 0          ARTS516           F
# 1          ARTS516           F
# 2          ARTS516           F
# 3          ARTS516           F
# 4          ARTS516           F
# ...            ...         ...
# 2233       ARTS497           E
# 2234       ARTS497           E
# 2235       ARTS497           E
# 2236       ARTS497           E
# 2237       ARTS575           E
#
# [2238 rows x 5 columns]

# %%
# Question 6 - Create a dataframe containing course numbers as columns
# First, we will create a dummy table containing the respective desired
# hiearchy 
data = pd.DataFrame(index=pd.Index(sorted(unique_students), name='Student'), 
                    columns=pd.Index(sorted(reg_merged['Course number'].unique()), name='Course'))

# For iterating, we will copy the merged table student names
unique_st_clean = reg_merged['Student name']

# We will double loop over each student and find what courses they are registered to
for st in sorted(unique_st_clean):
# Not the cleanest method but we will create a temp frame for each student
    reg_tmp = reg_merged[reg_merged['Student name'].str.match(st)]
# Now loop over each course number returned to the respective student
    for cs in reg_tmp['Course number'].values:
# Set the location in the original table to true now
        data[cs].loc[st] = 1 

# Change all nulls to 0
data = data.fillna(0)

# %%
data
# Out:
# Course                ARTS400  ARTS401  ARTS465  ARTS484  ARTS485  ARTS486
# Student
# ABella Abzug                0        1        0        0        0        1  \
# Al Gore                     0        0        0        0        0        1
# Al Hirt                     0        0        1        0        0        1
# Al Roker                    1        0        0        0        0        1
# Alan Alda                   0        0        0        0        0        0
# ...                       ...      ...      ...      ...      ...      ...
# Winona Ryder                0        0        0        0        0        1
# Wolfgang Puck               0        0        0        0        0        1
# Yogi Berra                  0        0        0        0        0        0
# Yoko Ono                    0        0        0        0        0        1
# state representative        0        1        0        0        0        1
#
# Course                ARTS488   ARTS491  ARTS492   ARTS493  ...  ARTS565
# Student                                                     ...
# ABella Abzug                 0        0         0        0  ...        0  \
# Al Gore                      0        0         0        1  ...        0
# Al Hirt                      0        0         0        0  ...        0
# Al Roker                     0        0         0        1  ...        0
# Alan Alda                    0        0         0        0  ...        0
# ...                        ...      ...       ...      ...  ...      ...
# Winona Ryder                 0        0         0        0  ...        0
# Wolfgang Puck                0        0         0        1  ...        0
# Yogi Berra                   0        0         0        0  ...        0
# Yoko Ono                     0        0         0        0  ...        0
# state representative         0        0         0        1  ...        0
#
# Course                ARTS569   ARTS571   ARTS573  ARTS575  ARTS577  ARTS581
# Student
# ABella Abzug                 0         0        0        0        0         1  \
# Al Gore                      0         0        0        0        0         0
# Al Hirt                      1         0        0        0        0         0
# Al Roker                     0         0        0        0        0         0
# Alan Alda                    0         0        0        0        0         0
# ...                        ...       ...      ...      ...      ...       ...
# Winona Ryder                 1         0        0        0        0         0
# Wolfgang Puck                0         0        0        0        0         0
# Yogi Berra                   0         0        0        0        0         0
# Yoko Ono                     0         0        0        0        0         0
# state representative         0         0        0        0        0         0
#
# Course                ARTS583   ARTS585   ARTS587
# Student
# ABella Abzug                 0         0        0
# Al Gore                      0         0        0
# Al Hirt                      0         0        0
# Al Roker                     0         0        0
# Alan Alda                    0         0        0
# ...                        ...       ...      ...
# Winona Ryder                 0         0        0
# Wolfgang Puck                0         0        1
# Yogi Berra                   0         0        0
# Yoko Ono                     0         0        0
# state representative         0         0        0
#
# [448 rows x 37 columns]
